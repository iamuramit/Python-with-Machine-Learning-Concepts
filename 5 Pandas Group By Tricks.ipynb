# %%
import pandas as pd

# %%
df = pd.read_csv('Dummy_Sales_Data_v1.csv')

# %%
df.shape
# Out:
# (9999, 12)

# %%
df.head(10)
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999920000        92             238  Not Delivered    8/8/2021
# 1  2181910000999920000        61             136  Not Delivered   10/3/2021
# 2  3239110000999930000        67             235  Not Delivered   9/27/2021
# 3  1112610000999910000        33             133    Not Shipped   7/30/2021
# 4  1548310000999910000        13             189  Not Delivered   8/15/2021
# 5  4934810000999940000        51             204  Not Delivered  11/13/2021
# 6  2750410000999920000        73             242  Not Delivered    7/8/2021
# 7  4797510000999940000        48             240      Delivered   10/4/2021
# 8  2804110000999920000        31             163    Not Shipped  12/23/2021
# 9  1735910000999910000        62             214  Not Delivered   8/14/2021
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df_group=df.groupby("Product_Category") 
#used .groupby() function on column Product Category in df 
#as below to get GroupBy object.

# %%
type(df_group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_group

# %%
df.Product_Category.nunique() 
#nunique() function on any column, which essentially gives 
#you number of unique values in that column
# Out:
# 5

# %%
df_group=df.groupby("Product_Category")
df_group.ngroups
# Out:
# 5

# %%
df.groupby("Product_Category").size() 
# size() to get the no. of rows in group
# Out:
# Product_Category
# Entertainment    1968
# Fashion          1971
# Healthcare       1953
# Home             2060
# Office           2011
# dtype: int64

# %%
df.groupby("Product_Category").count()
#counts the number of rows in each group
# Out:
#                   OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  \
# Product_Category
# Entertainment        1968      1968            1968    1968       1968
# Fashion              1971      1971            1971    1971       1971
# Healthcare           1953      1953            1953    1953       1953
# Home                 2060      2060            2060    2060       2060
# Office               2011      2011            2011    2011       2011
#
#                   Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# Product_Category
# Entertainment              1968                1968                 1959
# Fashion                    1971                1971                 1963
# Healthcare                 1953                1953                 1937
# Home                       2060                2060                 2049
# Office                     2011                2011                 2004
#
#                   Shipping_Address  Product_Code  OrderCode
# ...

# %%
type(df_group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_group.size()
# Out:
# Product_Category
# Entertainment    1968
# Fashion          1971
# Healthcare       1953
# Home             2060
# Office           2011
# dtype: int64

# %%
df_group.first()
#first record of in each group
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     4934810000999940000        51             204
# Fashion           1112610000999910000        33             133
# Healthcare        2951110000999920000        92             238
# Home              4337210000999940000        57             226
# Office            2181910000999920000        61             136
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment     Not Delivered  11/13/2021         Abdul                  32
# Fashion             Not Shipped   7/30/2021         Abdul                  34
# Healthcare        Not Delivered    8/8/2021         Pablo                  21
# Home                Not Shipped   9/27/2021          John                  24
# Office            Not Delivered   10/3/2021         Pablo                  34
#
# ...

# %%
df_group.last()
#last row once all the rows were grouped
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     1468010000999910000        53             229
# Fashion           2281610000999920000        18             117
# Healthcare        1847410000999910000        37             135
# Home              2301610000999920000        75             201
# Office            2385710000999920000        81             207
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment         Delivered   7/12/2021       Anthony                  25
# Fashion                 Shipped  12/23/2021        Stella                  22
# Healthcare              Shipped   10/3/2021         Maria                  30
# Home              Not Delivered  10/16/2021         Sofia                  20
# Office                Delivered  11/13/2021          Emma                  29
#
# ...

# %%
df_group.nth(3)
#extract row at any other position in each group
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     4030410000999940000        21             123
# Fashion           2804110000999920000        31             163
# Healthcare        4276410000999940000        83             224
# Home              3105110000999930000        79             213
# Office            1444810000999910000         5             119
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment     Not Delivered  10/10/2021       Kristen                  30
# Fashion             Not Shipped  12/23/2021         Abdul                  34
# Healthcare        Not Delivered   7/10/2021         Sofia                  24
# Home                  Delivered  10/26/2021         Abdul                  27
# Office              Not Shipped  10/13/2021        Stella                  33
#
# ...

# %%
df_group.get_group('Healthcare')
#used to select or extract only one group from the GroupBy object
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999920000        92             238  Not Delivered
# 6     2750410000999920000        73             242  Not Delivered
# 14    2559910000999920000        55             233  Not Delivered
# 19    4276410000999940000        83             224  Not Delivered
# 22    2111510000999920000        74             250      Delivered
# ...                   ...       ...             ...            ...
# 9981  4904910000999940000        73             209        Shipped
# 9983  4107210000999940000        57             162  Not Delivered
# 9986  1868610000999910000        30             162  Not Delivered
# 9988  4264110000999940000         4             187  Not Delivered
# 9995  1847410000999910000        37             135        Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0       8/8/2021       Healthcare         Pablo                  21
# ...

# %%
df[df["Product_Category"]=='Home']
#slicing a data frame through product_category
#you want to select all the rows where Product Category is ‘Home’
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 10    4337210000999940000        57             226    Not Shipped
# 13    4583610000999940000        46             208    Not Shipped
# 16    2808810000999920000        96             115      Delivered
# 18    3105110000999930000        79             213      Delivered
# 26    2958410000999920000        53             141        Shipped
# ...                   ...       ...             ...            ...
# 9975  3001610000999930000        80             174      Delivered
# 9977  3374310000999930000        37             156      Delivered
# 9980  1019210000999910000        37             159      Delivered
# 9982  3848110000999930000        13             108        Shipped
# 9994  2301610000999920000        75             201  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 10     9/27/2021             Home          John                  24
# ...

# %%
df_group = df.groupby("Product_Category")
df_group.get_group('Home')
# Slicing with .groupby() is 4X faster than with logical comparison

# %%
for name_of_group, content_of_group in df_group:
    print(name_of_group)
    print(content_of_group)
#It will list out the name and contents of each group.
# Out:
# Entertainment
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 5     4934810000999940000        51             204  Not Delivered
# 12    3882310000999930000        78             219      Delivered
# 20    2469010000999920000        15             156        Shipped
# 21    4030410000999940000        21             123  Not Delivered
# 23    3629310000999930000        78             155      Delivered
# ...                   ...       ...             ...            ...
# 9968  4220510000999940000        39             145        Shipped
# 9973  1074010000999910000         2             186  Not Delivered
# 9990  4241810000999940000        94             211    Not Shipped
# 9993  2363310000999920000        82             116        Shipped
# 9998  1468010000999910000        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 5     11/13/2021    Entertainment         Abdul                  32
# ...

# %%
#Create a groupby object
df_group = df.groupby("Product_Category")
#Select only required columns
df_columns = df_group[["UnitPrice(USD)","Quantity"]]
#Apply aggregate function
df_columns.mean()
# Out:
#                   UnitPrice(USD)   Quantity
# Product_Category
# Entertainment         176.038618  49.851118
# Fashion               176.117199  51.255200
# Healthcare            175.489503  50.905274
# Home                  175.354854  50.705340
# Office                175.127300  50.913476

# %%
df.groupby("Product_Category")[["Quantity"]].aggregate([min,max,sum,'mean'])
#suppose you want to get maximum, minimum, addition and 
#average of Quantity in each product category. 
#So the aggregate functions would be min, max, sum and mean
# Out:
#                  Quantity
#                       min  max     sum       mean
# Product_Category
# Entertainment           1  100   98107  49.851118
# Fashion                 1  100  101024  51.255200
# Healthcare              1  100   99418  50.905274
# Home                    1  100  104453  50.705340
# Office                  1  100  102387  50.913476

# %%
function_dictionary = {'OrderID':'count','Quantity':'mean'}
df.groupby("Product_Category").aggregate(function_dictionary)

#suppose you want to get a total orders and average quantity 
#in each product category. So the dictionary you will be passing to 
#.aggregate() will be — {‘OrderID’:’count’, ’Quantity’:’mean’}
#And you can get the desired output by simply passing this dictionary
# Out:
#                   OrderID   Quantity
# Product_Category
# Entertainment        1968  49.851118
# Fashion              1971  51.255200
# Healthcare           1953  50.905274
# Home                 2060  50.705340
# Office               2011  50.913476

# %%
df.groupby("Product_Category")[["Quantity"]].describe()
#to get basic statistical summary split by each group with a 
#single function — describe(). 
#You need to specify a required column and apply .describe()
# Out:
#                  Quantity
#                     count       mean        std  min   25%   50%   75%    max
# Product_Category
# Entertainment      1968.0  49.851118  29.184244  1.0  24.0  50.0  75.0  100.0
# Fashion            1971.0  51.255200  28.687947  1.0  27.0  51.0  76.0  100.0
# Healthcare         1953.0  50.905274  29.265929  1.0  25.0  50.0  77.0  100.0
# Home               2060.0  50.705340  28.917479  1.0  26.0  50.0  76.0  100.0
# Office             2011.0  50.913476  28.983277  1.0  26.0  52.0  76.0  100.0
