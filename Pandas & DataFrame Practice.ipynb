# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df["Fare"].min()
# Out:
# 0.0

# %%
df["Fare"].max()
# Out:
# 512.3292

# %%
df[df["Fare"]==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
len(df[df["Survived"]==0])
# Out:
# 549

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Fare"]==5]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 872          873         0       1  Carlsson, Mr. Frans Olof  male  33.0
#
#      SibSp  Parch Ticket  Fare        Cabin Embarked
# 872      0      0    695   5.0  B51 B53 B55        S

# %%
df1 = df[["Embarked","Survived"]].value_counts().reset_index()

# %%
df1
# Out:
#   Embarked  Survived    0
# 0        S         0  427
# 1        S         1  217
# 2        C         1   93
# 3        C         0   75
# 4        Q         0   47
# 5        Q         1   30

# %%
df1[(df1["Embarked"]=="C" ) & (df1["Survived"]==1)][0].values[0] / df1[(df1["Embarked"]=="C" )][0].sum()
# Out:
# 0.5535714285714286

# %%
df1[(df1["Embarked"]=="C" )][0].sum()
# Out:
# 168

# %%
df1[(df1["Embarked"]=="C" ) & (df1["Survived"]==1)][0].values[0] / df1[(df1["Embarked"]=="C" )][0].sum()
# Out:
# 0.5535714285714286

# %%
#to delete a column
#axis=1 means column wise and axis =0 means row wise
df1 = df.drop("PassengerId", axis=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#if we want to delete column in original dataframe use inplace =True
df.drop("PassengerId", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to insert new columns in existing dataframe
df['New']=1

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  New
# ...

# %%
df["Sex_Age"] = df["Sex"]+"_"+df["Age"].astype(str)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  New  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    1
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C    1
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    1
# 3  female  35.0      1      0            113803  53.1000  C123        S    1
# 4    male  35.0      0      0            373450   8.0500   NaN        S    1
#
#        Sex_Age
# 0    male_22.0
# 1  female_38.0
# 2  female_26.0
# ...

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# New           0
# Sex_Age       0
# dtype: int64

# %%
#to drop multiple column
df.drop(["Age", "Cabin"], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Embarked', 'New', 'Sex_Age'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Embarked  889 non-null    object
#  9   New       891 non-null    int64
#  10  Sex_Age   891 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 76.7+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass       SibSp       Parch        Fare    New
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.0
# mean     0.383838    2.308642    0.523008    0.381594   32.204208    1.0
# std      0.486592    0.836071    1.102743    0.806057   49.693429    0.0
# min      0.000000    1.000000    0.000000    0.000000    0.000000    1.0
# 25%      0.000000    2.000000    0.000000    0.000000    7.910400    1.0
# 50%      0.000000    3.000000    0.000000    0.000000   14.454200    1.0
# 75%      1.000000    3.000000    1.000000    0.000000   31.000000    1.0
# max      1.000000    3.000000    8.000000    6.000000  512.329200    1.0
