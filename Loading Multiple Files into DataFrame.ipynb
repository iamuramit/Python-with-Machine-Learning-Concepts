# %%
import pandas as pd

# %%
log1 = pd.read_csv('log1.txt')
log1.head()
# Out:
#             name           phone                   email         country
# 0  Damon Gregory  1-586-365-8458         orci@google.net  United Kingdom
# 1   Richard Kirk  (946) 317-6611        purus@icloud.net       Singapore
# 2    Dieter Howe  1-628-723-8328  gravida@protonmail.net          Norway
# 3     Alec Walls  (864) 881-4414   et.rutrum@hotmail.com          Norway
# 4   Damian White  1-708-404-5549  in.scelerisque@aol.org            Peru

# %%
log2= pd.read_csv('log2.txt')
log2.head()
# Out:
#                 name           phone                             email  \
# 0      Ezekiel Stein  1-263-951-9851                blandit@icloud.edu
# 1        Cailin Luna  1-846-476-6395          odio.vel.est@hotmail.com
# 2    Brenden Mueller  1-874-489-1722     cursus.nunc.mauris@hotmail.ca
# 3  Germaine Santiago  1-984-997-6672           et.euismod@outlook.couk
# 4      Caesar Larsen  1-746-457-2253  facilisis.eget.ipsum@hotmail.edu
#
#         country
# 0       Belgium
# 1  South Africa
# 2         India
# 3       Ukraine
# 4     Singapore

# %%
log3= pd.read_csv('log3.txt')
log3.head()
# Out:
#             name           phone                     email       country
# 0     Magee Ruiz  1-396-268-5342  bibendum.sed.est@aol.org     Singapore
# 1   Zena Mcclain  (938) 978-1236             in@yahoo.couk   Philippines
# 2  Naomi Mccarty  (608) 874-9269    risus.nulla@google.net  South Africa
# 3      Hop Moses  1-334-777-5292      diam.duis@google.org       Ukraine
# 4  Brandon Klein  (836) 600-8172     sit.amet@hotmail.couk        Turkey

# %%
df = pd.concat((log1, log2, log3))

# %%
df.head(15)
# Out:
#                 name           phone                             email  \
# 0      Damon Gregory  1-586-365-8458                   orci@google.net
# 1       Richard Kirk  (946) 317-6611                  purus@icloud.net
# 2        Dieter Howe  1-628-723-8328            gravida@protonmail.net
# 3         Alec Walls  (864) 881-4414             et.rutrum@hotmail.com
# 4       Damian White  1-708-404-5549            in.scelerisque@aol.org
# 0      Ezekiel Stein  1-263-951-9851                blandit@icloud.edu
# 1        Cailin Luna  1-846-476-6395          odio.vel.est@hotmail.com
# 2    Brenden Mueller  1-874-489-1722     cursus.nunc.mauris@hotmail.ca
# 3  Germaine Santiago  1-984-997-6672           et.euismod@outlook.couk
# 4      Caesar Larsen  1-746-457-2253  facilisis.eget.ipsum@hotmail.edu
# 0         Magee Ruiz  1-396-268-5342          bibendum.sed.est@aol.org
# 1       Zena Mcclain  (938) 978-1236                     in@yahoo.couk
# ...

# %%
df = pd.concat((log1, log2, log3), ignore_index=True) # to reset index
df.head(15)
# Out:
#                  name           phone                             email  \
# 0       Damon Gregory  1-586-365-8458                   orci@google.net
# 1        Richard Kirk  (946) 317-6611                  purus@icloud.net
# 2         Dieter Howe  1-628-723-8328            gravida@protonmail.net
# 3          Alec Walls  (864) 881-4414             et.rutrum@hotmail.com
# 4        Damian White  1-708-404-5549            in.scelerisque@aol.org
# 5       Ezekiel Stein  1-263-951-9851                blandit@icloud.edu
# 6         Cailin Luna  1-846-476-6395          odio.vel.est@hotmail.com
# 7     Brenden Mueller  1-874-489-1722     cursus.nunc.mauris@hotmail.ca
# 8   Germaine Santiago  1-984-997-6672           et.euismod@outlook.couk
# 9       Caesar Larsen  1-746-457-2253  facilisis.eget.ipsum@hotmail.edu
# 10         Magee Ruiz  1-396-268-5342          bibendum.sed.est@aol.org
# 11       Zena Mcclain  (938) 978-1236                     in@yahoo.couk
# ...

# %%
# what if you have 1000 of files

from glob import glob #use glob libraries

# %%
files = glob('log*')

# %%
files
# Out:
# ['log1.txt', 'log2.txt', 'log3.txt', 'log4.txt', 'log5.txt']

# %%
files.sort() # for sorting
files
# Out:
# ['log1.txt', 'log2.txt', 'log3.txt', 'log4.txt', 'log5.txt']

# %%
df = pd.concat((pd.read_csv(file) for file in files), ignore_index=True)

# %%
df.head()
# Out:
#             name           phone                   email         country
# 0  Damon Gregory  1-586-365-8458         orci@google.net  United Kingdom
# 1   Richard Kirk  (946) 317-6611        purus@icloud.net       Singapore
# 2    Dieter Howe  1-628-723-8328  gravida@protonmail.net          Norway
# 3     Alec Walls  (864) 881-4414   et.rutrum@hotmail.com          Norway
# 4   Damian White  1-708-404-5549  in.scelerisque@aol.org            Peru

# %%
df.head(30)
# Out:
#                  name           phone                                 email  \
# 0       Damon Gregory  1-586-365-8458                       orci@google.net
# 1        Richard Kirk  (946) 317-6611                      purus@icloud.net
# 2         Dieter Howe  1-628-723-8328                gravida@protonmail.net
# 3          Alec Walls  (864) 881-4414                 et.rutrum@hotmail.com
# 4        Damian White  1-708-404-5549                in.scelerisque@aol.org
# 5       Ezekiel Stein  1-263-951-9851                    blandit@icloud.edu
# 6         Cailin Luna  1-846-476-6395              odio.vel.est@hotmail.com
# 7     Brenden Mueller  1-874-489-1722         cursus.nunc.mauris@hotmail.ca
# 8   Germaine Santiago  1-984-997-6672               et.euismod@outlook.couk
# 9       Caesar Larsen  1-746-457-2253      facilisis.eget.ipsum@hotmail.edu
# 10         Magee Ruiz  1-396-268-5342              bibendum.sed.est@aol.org
# ...
